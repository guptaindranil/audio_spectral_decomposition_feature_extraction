# %%
import librosa
import librosa.display
import scipy as sp
import IPython.display as ipd 
import matplotlib.pyplot as plt 
import numpy as np 
import os

# %%
# load audio file
audio_path = "audio/voice.wav"
ipd.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal, sr = librosa.load(audio_path)

# %%
# plot waveform

plt.figure (figsize = (18 , 8))
librosa.display.waveshow(signal, sr = sr, alpha = 0.5)
plt.show()

# %%
# derive spectrum using FT
ft = sp.fft.fft(signal)
magnitude = np.absolute(ft)
frequency = np.linspace(0, sr, len(magnitude))

# %%
# plot spectrum
plt.figure (figsize = (18 , 8))
plt.plot (frequency[:5000], magnitude[:5000]) # magnitude apectrum
plt.xlabel ("Frequency (Hz)")
plt.ylabel ("magnitude")
plt.title("children_playing")
plt.savefig("ft/children_playing.png")
plt.show()

# %%
len(signal)
# Out:
# 661500

# %%
d = 1 / sr
print(f"Duration : {d:.6f}")
# Out:
# Duration : 0.000045

# %%
d_400_samples = 400 * d
d_400_samples
# Out:
# 0.018140589569160998

# %%
# zoom in to the waveform

samples = range(len(signal))
t = librosa.samples_to_time (samples, sr = sr)

plt.figure (figsize = (18 , 8))
plt.plot (t[10000 : 10400], signal [10000 : 10400])
plt.xlabel ("Time (s)")
plt.ylabel ("Amplitude")
plt.show()

# %%
# create a sinusoid

f = 523
phase = 0.
phase2 = 0.7

sin = 0.5 * np.sin(2 * np.pi * (f * t - phase))
sin2 = 0.5 * np.sin(2 * np.pi * (f * t - phase2))

plt.figure(figsize = (18 , 8))
plt.plot(t[10000 : 10400], sin[10000 : 10400], color = 'r')
plt.plot(t[10000 : 10400], sin2[10000 : 10400], color = 'b')

plt.xlabel ("Time (s)")
plt.ylabel ("Amplitude")
plt.show()

# %%
violin_file = "audio/violin_c.wav"
sax_file = "audio/sax.wav"
piano_file = "audio/piano_c.wav"
noise_file = "audio/noise.wav"

# %%
violin_c4, sr = librosa.load(violin_file)
